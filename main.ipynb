# %%
from cl_data_scraping import data_scrape1

# %%
import os
 
for x in os.listdir():
    if x.endswith(".json"):
        # Prints only text file present in My Folder
        print(x)
# Out:
# data_Bengaluru.json
# data_Chennai.json
# train_time.json

# %%
import os

for x in os.listdir('/data'):
    print(x)
# Out:
#     cityName  lat  long
# 0    Chennai   13    80
# 1  Bengaluru   12    77

# %%
#lat,logn,cityName
data_scrape1(13,80,"Chennai")
# Out:
# 2015-02-26 00:00:00+05:30
# 1424889000.0
# 2022-09-17 12:02:23.811934+05:30
# 1663396343.811934
# 2020-11-25 06:30:00

# %%
import time
a=time.time()
time.sleep((10))
b=time.time()
print(b-a)
# Out:
# 10.00067687034607

# %%
import lstm

# %%
lstm.model_train("Chennai")
# Out:
# ['no2', 'so2', 'pm2_5', 'pm10']
# Epoch 1/5
# 6/6 [==============================] - 2s 54ms/step - loss: 0.9894 - val_loss: nan
# Epoch 2/5
# 6/6 [==============================] - 0s 11ms/step - loss: 0.8240 - val_loss: nan
# Epoch 3/5
# 6/6 [==============================] - 0s 11ms/step - loss: 0.7304 - val_loss: nan
# Epoch 4/5
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6688 - val_loss: nan
# Epoch 5/5
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6399 - val_loss: nan

# %%
lstm.model_prediction("chennai",5,0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\sujatha\cl\backend\main.ipynb Cell 6 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/sujatha/cl/backend/main.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> lstm.model_prediction("chennai",5,0)
#
# NameError: name 'lstm' is not defined

# %%
from prediction import prediction

# %%
prediction(['Chennai'],10,'so2')
# Out:
# 1/1 [==============================] - 1s 801ms/step
#               Chennai
# Date
# 2022-10-03   4.204696
# 2022-10-04   5.584897
# 2022-10-05   8.328669
# 2022-10-06   8.376174
# 2022-10-07  10.461697
# 2022-10-08  10.474286
# 2022-10-09  12.690990
# 2022-10-10  17.124744
# 2022-10-11  19.993313
# 2022-10-12  27.349628

# %%
lstm.model_prediction("Chennai",10,1)
# Out:
# array([21.390455 , 18.327858 , 20.049269 ,  8.390078 ,  7.7544184,
#        11.063675 ,  6.7114944,  8.000216 ,  8.020531 ,  8.078544 ],
#       dtype=float32)

# %%
lstm.model_prediction("Chennai",10,0)
# Out:
# array([22.914267, 20.10001 , 21.681833, 10.968067, 10.383953, 13.424868,
#         9.425598, 10.609819, 10.628488, 10.681796], dtype=float32)

# %%
import prediction

# %%
a=prediction.prediction(["Chennai"],10,3)

# %%
from random import *
def fn(a):
    return 100-uniform(2.5, 20)
fn('a')
# Out:
# 84.00434385004576

# %%
y_pred_future1 = scaler.inverse_transform(prediction_copies)[:,0]

# %%
from datetime import datetime 
print(datetime.now())
# Out:
# 2022-09-17 12:07:43.352119

# %%
a=datetime.now().date()
str(a)
# Out:
# '2022-09-17'

# %%
import pandas as pd

# %%
city=pd.read_csv('cities.csv')
city
# Out:
#     cityName  lat  long
# 0    Chennai   13    80
# 1  Bengaluru   12    77

# %%
l=len(city.cityName)

# %%
for i in range(len(city.cityName)):
    print(city.lat[i])
    print(city.long[i])
    print(city.cityName[i])
# Out:
# 13
# 80
# Chennai
# 12
# 77
# Bengaluru

# %%
import pandas as pd
df=pd.read_csv("cities.csv")
df
# Out:
#     cityName  lat  long
# 0    Chennai   13    80
# 1  Bengaluru   12    77
# 2      delhi   28    77

# %%
df
# Out:
#     cityName  lat  long
# 0    Chennai   13    80
# 1  Bengaluru   12    77
# 2      delhi   28    77

# %%
df.drop(1)
# Out:
#   cityName  lat  long
# 0  Chennai   13    80
# 2    delhi   28    77

# %%
import pandas as pd
df=pd.read_csv("cities.csv")
df
# Out:
#     cityName  lat  long
# 0    Chennai   13    80
# 1  Bengaluru   12    77

# %%
flag2=0
for i in range(len(df)):
            if((df.loc[i]['lat']==13)&(df.loc[i]['long']==80)):
                flag2=0
                break
            else:
                flag2=1
flag2
# Out:
# 0

# %%
from rn import *
fn("5")
# Out:
# 86.23026214967815

# %%
import train
train.main()
# Out:
# 2015-02-26 00:00:00+05:30
# 1424889000.0
# 2022-09-23 17:24:04.727598+05:30
# 1663934044.727598
# 2020-11-25 06:30:00
# Epoch 1/100
# 84/84 [==============================] - 2s 6ms/step - loss: 0.6906 - val_loss: nan
# Epoch 2/100
# 84/84 [==============================] - 0s 4ms/step - loss: 0.5778 - val_loss: nan
# Epoch 3/100
# 84/84 [==============================] - 0s 4ms/step - loss: 0.5016 - val_loss: nan
# Epoch 4/100
# 84/84 [==============================] - 0s 4ms/step - loss: 0.4731 - val_loss: nan
# Epoch 5/100
# 84/84 [==============================] - 0s 4ms/step - loss: 0.4047 - val_loss: nan
# Epoch 6/100
# 84/84 [==============================] - 0s 4ms/step - loss: 0.3586 - val_loss: nan
# Epoch 7/100
# 84/84 [==============================] - 0s 4ms/step - loss: 0.3460 - val_loss: nan
# Epoch 8/100
# 84/84 [==============================] - 0s 4ms/step - loss: 0.3423 - val_loss: nan
# Epoch 9/100
# ...
